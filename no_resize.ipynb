# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'
import sys
import warnings
import gc
import random
import numpy as np
random.seed(1331)
np.random.seed(227)
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.color import rgb2gray
from skimage.morphology import label
from scipy import ndimage as ndi
import zipfile

from keras.models import Model, load_model
from keras.layers import Input, Dropout, BatchNormalization, Add, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Activation, ZeroPadding2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.regularizers import l2
from keras import backend as K

import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
K.set_session(session)

# Set some parameters
BS = 16
EPOCHS= 100
ORI_D = 101
INP_D = 128
PAD = INP_D-ORI_D
PAD_1 = PAD//2
PAD_2 = PAD-PAD_1
TRAIN_ZIP = '../input/train.zip'
TEST_ZIP = '../input/test.zip'
TRAIN_PATH = '../input/train/'
TEST_PATH = '../input/test/'
TRAIN_CSV = '../input/train.csv'
DEPTH_CSV = '../input/depths.csv'

if not os.path.exists(TRAIN_PATH):
    zip_ref = zipfile.ZipFile(TRAIN_ZIP, 'r')
    zip_ref.extractall(TRAIN_PATH)
    zip_ref.close()
if not os.path.exists(TEST_PATH):
    zip_ref = zipfile.ZipFile(TEST_ZIP, 'r')
    zip_ref.extractall(TEST_PATH)
    zip_ref.close()
if not os.path.exists('./models'):
    os.makedirs('./models')
print(os.listdir(TRAIN_PATH))
# Out:
# Using TensorFlow backend.
# ['masks', 'images']

# %%
def rle_encoding(x, order='F', to_str=True):
    dots = np.where(x.flatten(order=order) == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    if to_str:
        return ' '.join(str(y) for y in run_lengths)
    return run_lengths

# %%
train_csv = pd.read_csv(TRAIN_CSV)
depth_csv = pd.read_csv(DEPTH_CSV)
test_csv = depth_csv[~depth_csv.index.isin(train_csv.index)]
del depth_csv
gc.collect()
# Out:
# 7

# %%
X_train = []
Y_train = [] 

print('Getting train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_csv.id), total=len(train_csv.id)):
    path = TRAIN_PATH
    img = imread(path + 'images/' + id_ + '.png')[...,0].astype(np.uint8)
    assert img.ndim==2
    assert img.shape[0]==ORI_D and img.shape[1]==ORI_D
    X_train.append(img)
    mask = np.squeeze(imread(path + 'masks/' + id_ + '.png')>0).astype(np.uint8)
    assert mask.ndim==2
    Y_train.append(mask)
del img, mask
gc.collect()
# Out:
# Getting train images and masks ...
# 100%|██████████| 4000/4000 [00:01<00:00, 2053.57it/s]
# 0

# %%
# Check if training data looks all right
ix = np.random.randint(0, len(train_csv.id))
plt.imshow(X_train[ix], cmap='gray')
plt.show()
plt.imshow(Y_train[ix], cmap='gray')
plt.show()

# %%
# Define IoU metric
def score_numpy(Ys, Ps, th=0.45):
    iou_ths = np.arange(0.0, 1.0, 0.05)
    Ps = Ps.reshape(Ps.shape[0], -1).copy()
    Ys = Ys.reshape(Ys.shape[0], -1).copy()
    for n, P in enumerate(Ps):
        Ps[n] = P>th
    Ps = Ps.astype(np.bool)
    Ys = Ys.astype(np.bool)
    TPs = np.zeros_like(iou_ths, dtype=np.float32)
    FPs = np.zeros_like(iou_ths, dtype=np.float32)
    FNs = np.zeros_like(iou_ths, dtype=np.float32)
    for Y, P in zip(Ys, Ps):
        iou = (Y&P).sum() / ((Y|P).sum()+1e-9)
        Y_sum = Y.sum()
        P_sum = P.sum()
        for n, iou_th in enumerate(iou_ths):
            if iou>=iou_th: # TP
                TPs[n]+=1
            elif Y_sum<=0 and P_sum>0: # FP
                FPs[n]+=1
            elif Y_sum>0 and P_sum<=0: # FN
                FNs[n]+=1
    return np.mean(TPs / (TPs+FPs+FNs))

def score(label, pred):
    metric_value = tf.py_func(score_numpy, [label, pred], tf.float32)
    return metric_value
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=None) # scaler

def custom_loss(y_true, y_pred):
    
    def dice_coef(y_true, y_pred): 
        return (2.* K.sum(y_true*y_pred) + 1) / (K.sum(y_true) + K.sum(y_pred) + 1) # scaler
    
    s_dice_coef = dice_coef(y_true, y_pred) # scaler
    s_bce = K.mean(K.binary_crossentropy(y_true, y_pred)) # scaler
    loss = 0.5*s_bce - s_dice_coef + 1. # scaler [0, inf)
    
    loss = tf.Print(loss, [s_dice_coef], message='\ns_dice_coef:\t', summarize=10)
    loss = tf.Print(loss, [s_bce], message='\ns_bce:\t', summarize=10)
    
    return loss # scaler [0, inf)

# %%
def build_model():
    def conv(f, k=3, act='relu'):
        return Conv2D(f, (k, k), activation=act, kernel_initializer='he_normal', padding='same')
    def _res_conv(inputs, f, k=3): # very simple residual module
        channels = int(inputs.shape[-1])
        
        cs = inputs
        
        cs = BatchNormalization() (cs)
        cs = Activation('relu') (cs)
        cs = conv(f, 3, act=None) (cs)
        
        cs = Dropout(0.2) (cs)
        
        cs = BatchNormalization() (cs)
        cs = Activation('relu') (cs)
        cs = conv(f, 3, act=None) (cs)
        
        if f!=channels:
            t1 = conv(f, 1, None) (inputs) # identity mapping
        else:
            t1 = inputs
        
        out = Add()([t1, cs]) # t1 + c2
        return out
    def pool():
        return MaxPooling2D((2, 2))
    def up(inputs):
        upsampled = Conv2DTranspose(int(inputs.shape[-1]), (2, 2), strides=(2, 2), padding='same', kernel_regularizer=l2(0.0001)) (inputs)
        return upsampled
    
    inputs = Input(shape=(ORI_D, ORI_D, 1))
    preprocess1 = Lambda(lambda x: x/255.0) (inputs)
    pad1 = ZeroPadding2D(((PAD_1, PAD_2), (PAD_1, PAD_2))) (preprocess1)
    
    r = 16
    rep = 5 # 5*2*2*2 = 40
    mid_rep = 5 # 5*2 = 10 => 50+ layers resnet
    x = pad1
    
    skip_connections = []
    
    x = conv(r, 3, act='relu') (x)
    x = _res_conv(x, r, 3)
    skip_connections.append(x)
    x = pool() (x)
    
    for t in range(1, rep):
        x = _res_conv(x, r*int(2**t), 3)
        x = _res_conv(x, r*int(2**t), 3)
        skip_connections.append(x)
        x = pool() (x)
    
    for t in range(mid_rep):
        x = _res_conv(x, r*int(2**5))
    
    for t, s in zip(reversed(range(rep)), reversed(skip_connections)):
        x = up(x)
        x = concatenate([x, s])
        x = _res_conv(x, r*int(2**t), 3)
        x = _res_conv(x, r*int(2**t), 3)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid') (x)
    outputs_crop = Lambda(lambda x: x[:,PAD_1:-PAD_2,PAD_1:-PAD_2,:], name='align') (outputs)
    return Model([inputs], [outputs_crop])

# %%
model = build_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 101, 101, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 128, 128, 1)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 16) 160         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 128, 16) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 16) 64          dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 16) 0           conv2d_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 16)   64          max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   4640        activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 64, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 32)   128         dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 32)   544         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 32)   0           conv2d_6[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 32)   128         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 32)   9248        activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 32)   128         dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 32)   0           add_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 32)   128         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   18496       activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 64)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 64)   2112        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 64)   0           conv2d_11[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 64)   256         add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 64)   36928       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32, 32, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 64)   256         dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 64)   0           add_4[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)   0           add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  73856       activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 128)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 128)  512         dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 128)  8320        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 128)  0           conv2d_16[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 128)  512         add_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 128)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 128)  512         dropout_7[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 128)  0           add_6[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)    0           add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 128)    512         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    295168      activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 8, 8, 256)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 256)    1024        dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 256)    33024       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 256)    590080      activation_16[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 256)    0           conv2d_21[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 256)    1024        add_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 256)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 256)    590080      activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 8, 8, 256)    0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 256)    1024        dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 256)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 256)    590080      activation_18[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 256)    0           add_8[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 256)    0           add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 256)    1024        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, 4, 256)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 4, 4, 512)    1180160     activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 4, 4, 512)    0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 4, 4, 512)    2048        dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, 4, 512)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 4, 4, 512)    131584      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 4, 4, 512)    2359808     activation_20[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 512)    0           conv2d_26[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, 4, 512)    2048        add_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4, 4, 512)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 4, 4, 512)    2359808     activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 4, 4, 512)    0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, 4, 512)    2048        dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 4, 4, 512)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 4, 4, 512)    2359808     activation_22[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 512)    0           add_10[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, 4, 512)    2048        add_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, 4, 512)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 4, 4, 512)    2359808     activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 4, 4, 512)    0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 4, 4, 512)    2048        dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, 4, 512)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 4, 4, 512)    2359808     activation_24[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 512)    0           add_11[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 4, 4, 512)    2048        add_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 4, 4, 512)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 4, 4, 512)    2359808     activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 4, 4, 512)    0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, 4, 512)    2048        dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 4, 4, 512)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 4, 4, 512)    2359808     activation_26[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 4, 4, 512)    0           add_12[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, 4, 512)    2048        add_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, 4, 512)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 4, 4, 512)    2359808     activation_27[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 4, 4, 512)    0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 4, 4, 512)    2048        dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 4, 4, 512)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 4, 4, 512)    2359808     activation_28[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 4, 512)    0           add_13[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 8, 8, 512)    1049088     add_14[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           conv2d_transpose_1[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 768)    3072        concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 768)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 256)    1769728     activation_29[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 8, 8, 256)    0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 256)    1024        dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 8, 8, 256)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 256)    196864      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 256)    590080      activation_30[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 256)    0           conv2d_37[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 256)    1024        add_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 256)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 256)    590080      activation_31[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 8, 8, 256)    0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 256)    1024        dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 8, 8, 256)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 256)    590080      activation_32[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 256)    0           add_15[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 16, 16, 256)  262400      add_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 384)  0           conv2d_transpose_2[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 384)  1536        concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 16, 384)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 16, 16, 128)  442496      activation_33[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 16, 16, 128)  0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 16, 16, 128)  512         dropout_17[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 16, 16, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 128)  49280       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 16, 16, 128)  147584      activation_34[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 16, 16, 128)  0           conv2d_42[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16, 16, 128)  512         add_17[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 16, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 128)  147584      activation_35[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 16, 16, 128)  0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 16, 16, 128)  512         dropout_18[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 128)  147584      activation_36[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 16, 16, 128)  0           add_17[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 128)  65664       add_18[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 192)  0           conv2d_transpose_3[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 32, 32, 192)  768         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 192)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 64)   110656      activation_37[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 32, 32, 64)   0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 32, 32, 64)   256         dropout_19[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 64)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 64)   12352       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 64)   36928       activation_38[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 64)   0           conv2d_47[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 64)   256         add_19[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 64)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 64)   36928       activation_39[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 32, 32, 64)   0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 64)   256         dropout_20[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 64)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 64)   36928       activation_40[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 64)   0           add_19[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 64, 64)   16448       add_20[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 96)   0           conv2d_transpose_4[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 64, 64, 96)   384         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 64, 64, 96)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 64, 64, 32)   27680       activation_41[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 64, 64, 32)   0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 64, 64, 32)   128         dropout_21[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 64, 64, 32)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 64, 64, 32)   3104        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 64, 64, 32)   9248        activation_42[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 64, 64, 32)   0           conv2d_52[0][0]
#                                                                  conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 64, 64, 32)   128         add_21[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 64, 64, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 64, 64, 32)   9248        activation_43[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 64, 64, 32)   0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 64, 64, 32)   128         dropout_22[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 64, 64, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 32)   9248        activation_44[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 64, 64, 32)   0           add_21[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 128, 128, 32) 4128        add_22[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128, 128, 48) 0           conv2d_transpose_5[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 128, 128, 48) 192         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 128, 128, 48) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 128, 128, 16) 6928        activation_45[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 128, 128, 16) 0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 128, 128, 16) 64          dropout_23[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 128, 128, 16) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 128, 128, 16) 784         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 128, 128, 16) 2320        activation_46[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 128, 128, 16) 0           conv2d_57[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 128, 128, 16) 64          add_23[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 128, 128, 16) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 128, 128, 16) 2320        activation_47[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 128, 128, 16) 0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 128, 128, 16) 64          dropout_24[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 128, 128, 16) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 128, 128, 16) 2320        activation_48[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 128, 128, 16) 0           add_23[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 128, 128, 1)  17          add_24[0][0]
# __________________________________________________________________________________________________
# align (Lambda)                  (None, 101, 101, 1)  0           conv2d_60[0][0]
# ==================================================================================================
# Total params: 31,756,801
# Trainable params: 31,737,697
# Non-trainable params: 19,104
# __________________________________________________________________________________________________

# %%
from keras.utils import Sequence
import cv2
from sklearn.utils import shuffle
from skimage.transform import AffineTransform, warp
import copy
import imgaug as ia
from imgaug import augmenters as iaa

class data_generator(Sequence):
    def __init__(self, data, label, batch_size=4, training=True):
        self.data = data
        self.label= label
        self.batch_size = batch_size
        self.training = training
        self.seq_color = iaa.Sequential(
            [
                iaa.SomeOf((0, 2),
                    [
                        iaa.Dropout((0.01, 0.1)),
                        iaa.ContrastNormalization((0.95, 1.05)),
                        
                    ], random_order=True
                )
            ], random_order=True
        )
    def __len__(self):
        return int(np.ceil(float(len(self.data))/self.batch_size))
    def on_epoch_end(self):
        if self.training: self.data, self.label = shuffle(self.data, self.label)
    def __getitem__(self, i):
        l_bound =  i    * self.batch_size
        r_bound = (i+1) * self.batch_size
        if r_bound>len(self.data): # ensure every iteration has the same batch size
            r_bound = len(self.data)
            l_bound = r_bound - self.batch_size
        dat_que = np.empty((self.batch_size, ORI_D, ORI_D, 1), dtype=np.uint8)
        lab_que = np.empty((self.batch_size, ORI_D, ORI_D, 1), dtype=np.uint8)
        for n, index in enumerate(range(l_bound, r_bound)):
            img = copy.deepcopy(self.data[index]).astype(np.float32) / 255.
            lab = copy.deepcopy(self.label[index]).astype(np.float32)
            if self.training:
                if np.random.rand() < .5: # flip horizontal
                    img = np.flip(img, 1)
                    lab = np.flip(lab, 1)

                if np.random.rand()<0.2:
                    a = .02 # amptitude
                    t  = np.random.uniform(1-a,1+a)
                    img = np.clip(img * t, 0, 1) # channel wise amplify
                
                if np.random.rand()<0.2:
                    up = np.random.uniform(0.975, 1.025) # change gamma
                    img = np.clip(img**up, 0, 1) # apply gamma and convert back to range [0,255]
                
                if np.random.rand()<0.3:
                    sigma = np.random.rand()*0.02
                    img = np.clip(img + np.random.randn(*img.shape)*sigma, 0, 1)
                
                if np.random.rand() < 0.4:
                    crop_ratio = np.random.uniform(0.01, 0.15, size=4)
                    u, r, d, l = np.round(crop_ratio * np.array([img.shape[0], img.shape[1]]*2)).astype(np.uint8)
                    img = img[u:-d,l:-r] # crop image
                    lab = lab[u:-d,l:-r] # crop image
                
                if np.random.rand() < 0.3:
                    img = np.clip(self.seq_color.augment_image(img), 0, 1)
            ### end of data augmentation ###

            img = np.clip(img.astype(np.float32)*255,0, 255).astype(np.uint8)
            lab = np.round(np.clip(lab.astype(np.float32),0, 1)).astype(np.uint8)
            
            if img.shape[0]!=ORI_D or img.shape[1]!=ORI_D:
                diffr = ORI_D-img.shape[0] # must >= 0
                diffc = ORI_D-img.shape[1] # must >= 0
                padr1 = np.random.randint(diffr+1)
                padr2 = diffr-padr1
                padc1 = np.random.randint(diffc+1)
                padc2 = diffc-padc1
                img = np.pad(img, ((padr1,padr2),(padc1,padc2)), 'wrap')
                lab = np.pad(lab, ((padr1,padr2),(padc1,padc2)), 'wrap')

            dat_que[n,...,0] = img
            lab_que[n,...,0] = lab
        return dat_que, lab_que

# %%
coverage = np.asarray([ x.sum() / (ORI_D**2) for x in Y_train ])
coverage_lev = np.linspace(0, 1, 30)
import bisect
coverage_stratify = []
for cov in coverage:
    coverage_stratify.append(bisect.bisect_left(coverage_lev, cov))

# %%
# https://www.surveysystem.com/sscalc.htm
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=600, shuffle=True, stratify = coverage_stratify)
del coverage, coverage_lev, coverage_stratify

# %%
train_generator = data_generator(X_train, Y_train, batch_size=BS, training=True)

# %%
import multiprocessing
from keras.optimizers import Adam

checkpointer_best = ModelCheckpoint('./models/best.h5', monitor='val_score', mode='max', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8,
                              patience=2, min_lr=0.00001, mode='min')
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=10)
model.compile(loss=custom_loss, optimizer=Adam(lr=0.001), metrics=[mean_iou, score, 'accuracy'])
history = model.fit_generator(train_generator,
                              steps_per_epoch= len(train_generator), 
                              epochs=EPOCHS, 
                              validation_data=(np.asarray(X_val)[...,np.newaxis], np.asarray(Y_val)[...,np.newaxis]), 
                              callbacks=[checkpointer_best, reduce_lr, early_stop],
                              workers= max(1, multiprocessing.cpu_count()-3),
                              use_multiprocessing= True,
                              shuffle = True
                              )
# Out:
# Epoch 1/100
# 213/213 [==============================] - 37s 175ms/step - loss: 0.8993 - mean_iou: 0.4825 - score: 0.3436 - acc: 0.7659 - val_loss: 0.7754 - val_mean_iou: 0.5453 - val_score: 0.5449 - val_acc: 0.8164
#
# Epoch 00001: val_score improved from -inf to 0.54494, saving model to ./models/best.h5
# Epoch 2/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.7109 - mean_iou: 0.5684 - score: 0.4137 - acc: 0.8331 - val_loss: 0.6716 - val_mean_iou: 0.5887 - val_score: 0.5555 - val_acc: 0.8382
#
# Epoch 00002: val_score improved from 0.54494 to 0.55547, saving model to ./models/best.h5
# Epoch 3/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.6245 - mean_iou: 0.6009 - score: 0.4677 - acc: 0.8555 - val_loss: 0.7505 - val_mean_iou: 0.6128 - val_score: 0.5747 - val_acc: 0.8021
#
# Epoch 00003: val_score improved from 0.55547 to 0.57474, saving model to ./models/best.h5
# Epoch 4/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.5930 - mean_iou: 0.6208 - score: 0.4694 - acc: 0.8638 - val_loss: 0.4109 - val_mean_iou: 0.6289 - val_score: 0.6957 - val_acc: 0.9167
#
# Epoch 00004: val_score improved from 0.57474 to 0.69569, saving model to ./models/best.h5
# Epoch 5/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.6131 - mean_iou: 0.6327 - score: 0.4815 - acc: 0.8507 - val_loss: 0.4573 - val_mean_iou: 0.6348 - val_score: 0.6640 - val_acc: 0.9113
#
# Epoch 00005: val_score did not improve from 0.69569
# Epoch 6/100
# 160/213 [=====================>........] - ETA: 6s - loss: 0.5821 - mean_iou: 0.6365 - score: nan - acc: 0.8599
# /hdd/home/peter0749/virtualenv/tf_keras/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# 213/213 [==============================] - 27s 125ms/step - loss: 0.5708 - mean_iou: 0.6372 - score: nan - acc: 0.8636 - val_loss: 0.3641 - val_mean_iou: 0.6420 - val_score: 0.6673 - val_acc: 0.9223
#
# Epoch 00006: val_score did not improve from 0.69569
# Epoch 7/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.5663 - mean_iou: 0.6459 - score: 0.4950 - acc: 0.8654 - val_loss: 0.4626 - val_mean_iou: 0.6490 - val_score: 0.6184 - val_acc: 0.9084
#
# Epoch 00007: val_score did not improve from 0.69569
# Epoch 8/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.5693 - mean_iou: 0.6518 - score: 0.4990 - acc: 0.8663 - val_loss: 0.4235 - val_mean_iou: 0.6542 - val_score: 0.6514 - val_acc: 0.8949
#
# Epoch 00008: val_score did not improve from 0.69569
# Epoch 9/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.5370 - mean_iou: 0.6570 - score: 0.5317 - acc: 0.8738 - val_loss: 0.3838 - val_mean_iou: 0.6598 - val_score: 0.6290 - val_acc: 0.8989
#
# Epoch 00009: val_score did not improve from 0.69569
# Epoch 10/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.5116 - mean_iou: 0.6630 - score: nan - acc: 0.8796 - val_loss: 0.3539 - val_mean_iou: 0.6651 - val_score: 0.6069 - val_acc: 0.9191
#
# Epoch 00010: val_score did not improve from 0.69569
# Epoch 11/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4831 - mean_iou: 0.6680 - score: 0.5633 - acc: 0.8869 - val_loss: 0.3766 - val_mean_iou: 0.6709 - val_score: 0.6715 - val_acc: 0.9023
#
# Epoch 00011: val_score did not improve from 0.69569
# Epoch 12/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4645 - mean_iou: 0.6735 - score: 0.5759 - acc: 0.8900 - val_loss: 0.3376 - val_mean_iou: 0.6765 - val_score: 0.6454 - val_acc: 0.9190
#
# Epoch 00012: val_score did not improve from 0.69569
# Epoch 13/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4847 - mean_iou: 0.6785 - score: 0.5606 - acc: 0.8846 - val_loss: 0.3478 - val_mean_iou: 0.6804 - val_score: 0.7021 - val_acc: 0.9123
#
# Epoch 00013: val_score improved from 0.69569 to 0.70213, saving model to ./models/best.h5
# Epoch 14/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4917 - mean_iou: 0.6815 - score: 0.5636 - acc: 0.8813 - val_loss: 0.3027 - val_mean_iou: 0.6834 - val_score: 0.6638 - val_acc: 0.9332
#
# Epoch 00014: val_score did not improve from 0.70213
# Epoch 15/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4809 - mean_iou: 0.6852 - score: 0.5694 - acc: 0.8862 - val_loss: 0.3440 - val_mean_iou: 0.6866 - val_score: 0.6727 - val_acc: 0.9149
#
# Epoch 00015: val_score did not improve from 0.70213
# Epoch 16/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4672 - mean_iou: 0.6882 - score: 0.5753 - acc: 0.8896 - val_loss: 0.2844 - val_mean_iou: 0.6898 - val_score: 0.7114 - val_acc: 0.9345
#
# Epoch 00016: val_score improved from 0.70213 to 0.71142, saving model to ./models/best.h5
# Epoch 17/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4687 - mean_iou: 0.6913 - score: 0.5731 - acc: 0.8881 - val_loss: 0.2959 - val_mean_iou: 0.6926 - val_score: 0.7433 - val_acc: 0.9270
#
# Epoch 00017: val_score improved from 0.71142 to 0.74334, saving model to ./models/best.h5
# Epoch 18/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4651 - mean_iou: 0.6940 - score: nan - acc: 0.8917 - val_loss: 0.3037 - val_mean_iou: 0.6953 - val_score: 0.7220 - val_acc: 0.9289
#
# Epoch 00018: val_score did not improve from 0.74334
# Epoch 19/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4420 - mean_iou: 0.6968 - score: 0.5815 - acc: 0.8981 - val_loss: 0.2846 - val_mean_iou: 0.6985 - val_score: 0.7453 - val_acc: 0.9286
#
# Epoch 00019: val_score improved from 0.74334 to 0.74533, saving model to ./models/best.h5
# Epoch 20/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4393 - mean_iou: 0.6998 - score: nan - acc: 0.8970 - val_loss: 0.4423 - val_mean_iou: 0.7010 - val_score: 0.6403 - val_acc: 0.8803
#
# Epoch 00020: val_score did not improve from 0.74533
# Epoch 21/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4569 - mean_iou: 0.7019 - score: 0.5822 - acc: 0.8927 - val_loss: 0.2684 - val_mean_iou: 0.7029 - val_score: 0.7400 - val_acc: 0.9334
#
# Epoch 00021: val_score did not improve from 0.74533
# Epoch 22/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4466 - mean_iou: 0.7039 - score: 0.5899 - acc: 0.8944 - val_loss: 0.2891 - val_mean_iou: 0.7050 - val_score: 0.7780 - val_acc: 0.9311
#
# Epoch 00022: val_score improved from 0.74533 to 0.77798, saving model to ./models/best.h5
# Epoch 23/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4055 - mean_iou: 0.7065 - score: nan - acc: 0.9050 - val_loss: 0.2617 - val_mean_iou: 0.7080 - val_score: 0.7427 - val_acc: 0.9377
#
# Epoch 00023: val_score did not improve from 0.77798
# Epoch 24/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4005 - mean_iou: 0.7092 - score: 0.6236 - acc: 0.9047 - val_loss: 0.3397 - val_mean_iou: 0.7106 - val_score: 0.6966 - val_acc: 0.9175
#
# Epoch 00024: val_score did not improve from 0.77798
# Epoch 25/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4049 - mean_iou: 0.7119 - score: 0.6145 - acc: 0.9033 - val_loss: 0.3270 - val_mean_iou: 0.7128 - val_score: 0.7157 - val_acc: 0.9186
#
# Epoch 00025: val_score did not improve from 0.77798
# Epoch 26/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4334 - mean_iou: 0.7135 - score: nan - acc: 0.8951 - val_loss: 0.2409 - val_mean_iou: 0.7143 - val_score: 0.7648 - val_acc: 0.9461
#
# Epoch 00026: val_score did not improve from 0.77798
# Epoch 27/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4059 - mean_iou: 0.7151 - score: nan - acc: 0.9033 - val_loss: 0.2554 - val_mean_iou: 0.7163 - val_score: 0.7515 - val_acc: 0.9418
#
# Epoch 00027: val_score did not improve from 0.77798
# Epoch 28/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4023 - mean_iou: 0.7174 - score: 0.6254 - acc: 0.9046 - val_loss: 0.2727 - val_mean_iou: 0.7183 - val_score: 0.7480 - val_acc: 0.9353
#
# Epoch 00028: val_score did not improve from 0.77798
# Epoch 29/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4061 - mean_iou: 0.7192 - score: nan - acc: 0.9052 - val_loss: 0.2743 - val_mean_iou: 0.7201 - val_score: 0.7235 - val_acc: 0.9337
#
# Epoch 00029: val_score did not improve from 0.77798
# Epoch 30/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.4163 - mean_iou: 0.7207 - score: 0.6075 - acc: 0.9000 - val_loss: 0.2804 - val_mean_iou: 0.7215 - val_score: 0.7652 - val_acc: 0.9319
#
# Epoch 00030: val_score did not improve from 0.77798
# Epoch 31/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3835 - mean_iou: 0.7225 - score: 0.6355 - acc: 0.9097 - val_loss: 0.2955 - val_mean_iou: 0.7234 - val_score: 0.7305 - val_acc: 0.9284
#
# Epoch 00031: val_score did not improve from 0.77798
# Epoch 32/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3795 - mean_iou: 0.7242 - score: 0.6375 - acc: 0.9099 - val_loss: 0.2433 - val_mean_iou: 0.7251 - val_score: 0.7673 - val_acc: 0.9435
#
# Epoch 00032: val_score did not improve from 0.77798
# Epoch 33/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3883 - mean_iou: 0.7259 - score: 0.6318 - acc: 0.9083 - val_loss: 0.2464 - val_mean_iou: 0.7268 - val_score: 0.7465 - val_acc: 0.9426
#
# Epoch 00033: val_score did not improve from 0.77798
# Epoch 34/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3614 - mean_iou: 0.7276 - score: nan - acc: 0.9125 - val_loss: 0.2667 - val_mean_iou: 0.7286 - val_score: 0.7523 - val_acc: 0.9381
#
# Epoch 00034: val_score did not improve from 0.77798
# Epoch 35/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3737 - mean_iou: 0.7293 - score: 0.6564 - acc: 0.9118 - val_loss: 0.2659 - val_mean_iou: 0.7302 - val_score: 0.7766 - val_acc: 0.9339
#
# Epoch 00035: val_score did not improve from 0.77798
# Epoch 36/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3639 - mean_iou: 0.7310 - score: 0.6416 - acc: 0.9145 - val_loss: 0.2351 - val_mean_iou: 0.7319 - val_score: 0.7738 - val_acc: 0.9455
#
# Epoch 00036: val_score did not improve from 0.77798
# Epoch 37/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3707 - mean_iou: 0.7326 - score: 0.6468 - acc: 0.9101 - val_loss: 0.2499 - val_mean_iou: 0.7333 - val_score: 0.7658 - val_acc: 0.9420
#
# Epoch 00037: val_score did not improve from 0.77798
# Epoch 38/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3949 - mean_iou: 0.7339 - score: nan - acc: 0.9069 - val_loss: 0.2419 - val_mean_iou: 0.7345 - val_score: 0.7646 - val_acc: 0.9444
#
# Epoch 00038: val_score did not improve from 0.77798
# Epoch 39/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3486 - mean_iou: 0.7353 - score: 0.6484 - acc: 0.9175 - val_loss: 0.2412 - val_mean_iou: 0.7361 - val_score: 0.7775 - val_acc: 0.9468
#
# Epoch 00039: val_score did not improve from 0.77798
# Epoch 40/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3649 - mean_iou: 0.7367 - score: 0.6427 - acc: 0.9132 - val_loss: 0.2305 - val_mean_iou: 0.7375 - val_score: 0.7786 - val_acc: 0.9454
#
# Epoch 00040: val_score improved from 0.77798 to 0.77856, saving model to ./models/best.h5
# Epoch 41/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3511 - mean_iou: 0.7381 - score: 0.6507 - acc: 0.9173 - val_loss: 0.2468 - val_mean_iou: 0.7389 - val_score: 0.7671 - val_acc: 0.9425
#
# Epoch 00041: val_score did not improve from 0.77856
# Epoch 42/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3245 - mean_iou: 0.7397 - score: nan - acc: 0.9224 - val_loss: 0.2358 - val_mean_iou: 0.7406 - val_score: 0.7879 - val_acc: 0.9423
#
# Epoch 00042: val_score improved from 0.77856 to 0.78791, saving model to ./models/best.h5
# Epoch 43/100
# 213/213 [==============================] - 27s 126ms/step - loss: 0.3481 - mean_iou: 0.7412 - score: 0.6601 - acc: 0.9181 - val_loss: 0.2337 - val_mean_iou: 0.7419 - val_score: 0.7803 - val_acc: 0.9474
#
# Epoch 00043: val_score did not improve from 0.78791
# Epoch 44/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3382 - mean_iou: 0.7426 - score: 0.6679 - acc: 0.9190 - val_loss: 0.2435 - val_mean_iou: 0.7433 - val_score: 0.7803 - val_acc: 0.9430
#
# Epoch 00044: val_score did not improve from 0.78791
# Epoch 45/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3403 - mean_iou: 0.7438 - score: 0.6659 - acc: 0.9194 - val_loss: 0.2652 - val_mean_iou: 0.7446 - val_score: 0.7709 - val_acc: 0.9344
#
# Epoch 00045: val_score did not improve from 0.78791
# Epoch 46/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3377 - mean_iou: 0.7453 - score: 0.6621 - acc: 0.9221 - val_loss: 0.2298 - val_mean_iou: 0.7459 - val_score: 0.7809 - val_acc: 0.9456
#
# Epoch 00046: val_score did not improve from 0.78791
# Epoch 47/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3557 - mean_iou: 0.7465 - score: 0.6647 - acc: 0.9150 - val_loss: 0.2540 - val_mean_iou: 0.7470 - val_score: 0.7735 - val_acc: 0.9378
#
# Epoch 00047: val_score did not improve from 0.78791
# Epoch 48/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3455 - mean_iou: 0.7474 - score: 0.6521 - acc: 0.9172 - val_loss: 0.2345 - val_mean_iou: 0.7480 - val_score: 0.7708 - val_acc: 0.9478
#
# Epoch 00048: val_score did not improve from 0.78791
# Epoch 49/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3595 - mean_iou: 0.7485 - score: 0.6439 - acc: 0.9141 - val_loss: 0.2438 - val_mean_iou: 0.7489 - val_score: 0.7687 - val_acc: 0.9426
#
# Epoch 00049: val_score did not improve from 0.78791
# Epoch 50/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3541 - mean_iou: 0.7493 - score: 0.6543 - acc: 0.9173 - val_loss: 0.2576 - val_mean_iou: 0.7499 - val_score: 0.7632 - val_acc: 0.9373
#
# Epoch 00050: val_score did not improve from 0.78791
# Epoch 51/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3774 - mean_iou: 0.7501 - score: 0.6343 - acc: 0.9104 - val_loss: 0.2431 - val_mean_iou: 0.7506 - val_score: 0.7687 - val_acc: 0.9425
#
# Epoch 00051: val_score did not improve from 0.78791
# Epoch 52/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3257 - mean_iou: 0.7512 - score: nan - acc: 0.9255 - val_loss: 0.2410 - val_mean_iou: 0.7518 - val_score: 0.7729 - val_acc: 0.9446
#
# Epoch 00052: val_score did not improve from 0.78791
# Epoch 53/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3541 - mean_iou: 0.7521 - score: 0.6588 - acc: 0.9160 - val_loss: 0.2386 - val_mean_iou: 0.7526 - val_score: 0.7799 - val_acc: 0.9452
#
# Epoch 00053: val_score did not improve from 0.78791
# Epoch 54/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3679 - mean_iou: 0.7529 - score: 0.6384 - acc: 0.9144 - val_loss: 0.2533 - val_mean_iou: 0.7533 - val_score: 0.7759 - val_acc: 0.9382
#
# Epoch 00054: val_score did not improve from 0.78791
# Epoch 55/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3434 - mean_iou: 0.7538 - score: 0.6633 - acc: 0.9199 - val_loss: 0.2361 - val_mean_iou: 0.7543 - val_score: 0.7895 - val_acc: 0.9441
#
# Epoch 00055: val_score improved from 0.78791 to 0.78945, saving model to ./models/best.h5
# Epoch 56/100
# 213/213 [==============================] - 27s 125ms/step - loss: 0.3270 - mean_iou: 0.7547 - score: 0.6685 - acc: 0.9229 - val_loss: 0.2334 - val_mean_iou: 0.7552 - val_score: 0.7769 - val_acc: 0.9454
#
# Epoch 00056: val_score did not improve from 0.78945

# %%
del train_generator
gc.collect()
# Out:
# 147804

# %%
plt.plot(history.history['mean_iou'])
plt.plot(history.history['val_mean_iou'])
plt.title('model mean_iou')
plt.ylabel('mean_iou')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['score'])
plt.plot(history.history['val_score'])
plt.title('LB')
plt.ylabel('LB @threshold=0.45')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper right')
plt.show()

# %%
model.load_weights('./models/best.h5')
preds_val = model.predict(np.asarray(X_val)[...,np.newaxis], batch_size=BS, verbose=1)
# Out:
# 600/600 [==============================] - 2s 3ms/step

# %%
threshold_choices = np.arange(0.1, 1.0, 0.01)
best_threshold = 0.1
best_score = 0

for th in threshold_choices:
    Ys = np.squeeze(Y_val)
    Ps = np.squeeze(preds_val)
    score = score_numpy(Ys, Ps, th)
    print('score: {:.4f} @threshold: {:.2f}'.format(score, th))
    if score>best_score:
        best_score = score
        best_threshold = th
print('best threshold: {:.2f}, best score: {:.8f}'.format(best_threshold, best_score))
# Out:
# score: 0.7321 @threshold: 0.10
# score: 0.7346 @threshold: 0.11
# score: 0.7512 @threshold: 0.12
# score: 0.7514 @threshold: 0.13
# score: 0.7516 @threshold: 0.14
# score: 0.7537 @threshold: 0.15
# score: 0.7575 @threshold: 0.16
# score: 0.7578 @threshold: 0.17
# score: 0.7560 @threshold: 0.18
# score: 0.7579 @threshold: 0.19
# score: 0.7579 @threshold: 0.20
# score: 0.7619 @threshold: 0.21
# score: 0.7621 @threshold: 0.22
# score: 0.7640 @threshold: 0.23
# score: 0.7638 @threshold: 0.24
# score: 0.7660 @threshold: 0.25
# score: 0.7661 @threshold: 0.26
# score: 0.7684 @threshold: 0.27
# score: 0.7684 @threshold: 0.28
# score: 0.7664 @threshold: 0.29
# score: 0.7683 @threshold: 0.30
# score: 0.7702 @threshold: 0.31
# score: 0.7701 @threshold: 0.32
# score: 0.7701 @threshold: 0.33
# score: 0.7700 @threshold: 0.34
# score: 0.7700 @threshold: 0.35
# score: 0.7720 @threshold: 0.36
# score: 0.7740 @threshold: 0.37
# score: 0.7741 @threshold: 0.38
# score: 0.7781 @threshold: 0.39
# score: 0.7782 @threshold: 0.40
# score: 0.7781 @threshold: 0.41
# score: 0.7781 @threshold: 0.42
# score: 0.7782 @threshold: 0.43
# score: 0.7803 @threshold: 0.44
# score: 0.7801 @threshold: 0.45
# score: 0.7800 @threshold: 0.46
# score: 0.7779 @threshold: 0.47
# score: 0.7777 @threshold: 0.48
# score: 0.7778 @threshold: 0.49
# score: 0.7777 @threshold: 0.50
# score: 0.7775 @threshold: 0.51
# score: 0.7795 @threshold: 0.52
# score: 0.7795 @threshold: 0.53
# score: 0.7795 @threshold: 0.54
# score: 0.7793 @threshold: 0.55
# score: 0.7793 @threshold: 0.56
# score: 0.7792 @threshold: 0.57
# score: 0.7791 @threshold: 0.58
# score: 0.7789 @threshold: 0.59
# score: 0.7786 @threshold: 0.60
# score: 0.7783 @threshold: 0.61
# score: 0.7803 @threshold: 0.62
# score: 0.7803 @threshold: 0.63
# score: 0.7782 @threshold: 0.64
# score: 0.7800 @threshold: 0.65
# score: 0.7798 @threshold: 0.66
# score: 0.7818 @threshold: 0.67
# score: 0.7817 @threshold: 0.68
# score: 0.7819 @threshold: 0.69
# score: 0.7778 @threshold: 0.70
# score: 0.7758 @threshold: 0.71
# score: 0.7696 @threshold: 0.72
# score: 0.7696 @threshold: 0.73
# score: 0.7692 @threshold: 0.74
# score: 0.7692 @threshold: 0.75
# score: 0.7688 @threshold: 0.76
# score: 0.7727 @threshold: 0.77
# score: 0.7746 @threshold: 0.78
# score: 0.7746 @threshold: 0.79
# score: 0.7785 @threshold: 0.80
# score: 0.7760 @threshold: 0.81
# score: 0.7780 @threshold: 0.82
# score: 0.7758 @threshold: 0.83
# score: 0.7756 @threshold: 0.84
# score: 0.7753 @threshold: 0.85
# score: 0.7732 @threshold: 0.86
# score: 0.7728 @threshold: 0.87
# score: 0.7748 @threshold: 0.88
# score: 0.7761 @threshold: 0.89
# score: 0.7778 @threshold: 0.90
# score: 0.7774 @threshold: 0.91
# score: 0.7701 @threshold: 0.92
# score: 0.7699 @threshold: 0.93
# score: 0.7674 @threshold: 0.94
# score: 0.7729 @threshold: 0.95
# score: 0.7738 @threshold: 0.96
# score: 0.7789 @threshold: 0.97
# score: 0.7755 @threshold: 0.98
# score: 0.7739 @threshold: 0.99
# best threshold: 0.69, best score: 0.78194678

# %%
# Perform a sanity check on some random training samples
ix = np.random.randint(0, len(preds_val))
print(ix)
shape = Y_val[ix].shape[:2]
plt.imshow(X_val[ix])
plt.show()
plt.imshow(Y_val[ix])
plt.show()
preds = np.squeeze(preds_val[ix])
preds = preds>best_threshold
plt.imshow(preds)
plt.show()
# Out:
# 509

# %%
del X_train, Y_train
gc.collect()
# Out:
# 15199

# %%
sub_rles = []
x_test = []
print('Reading testing data...')
for n, id_ in tqdm(enumerate(test_csv.id), total=len(test_csv.id)):
    path = TEST_PATH
    img = imread(path + 'images/' + id_ + '.png')[...,0].astype(np.uint8)[...,np.newaxis]
    x_test.append(img)

print('Predicting...')
preds = model.predict(np.asarray(x_test), batch_size=BS, verbose=1)[...,0]
print('Convert to RLE...')
for pred in tqdm(preds, total=len(preds)):
    pred_thresholded = (pred>best_threshold).astype(np.bool)
    rle = rle_encoding(pred_thresholded)
    sub_rles.append(rle)
sub = pd.DataFrame()
sub['id'] = test_csv.id
sub['rle_mask'] = sub_rles
sub.to_csv('salty.csv', index=False)
print('Done!')
# Out:
#   2%|▏         | 287/18000 [00:00<00:06, 2862.24it/s]
# Reading testing data...
# 100%|██████████| 18000/18000 [00:06<00:00, 2911.78it/s]
# Predicting...
# 18000/18000 [==============================] - 31s 2ms/step
#   0%|          | 0/18000 [00:00<?, ?it/s]
# Convert to RLE...
# 100%|██████████| 18000/18000 [00:09<00:00, 1923.32it/s]
# Done!
