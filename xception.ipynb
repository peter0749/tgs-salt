# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'
import sys
import warnings
import gc
import random
import numpy as np
random.seed(11)
np.random.seed(67)
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.color import rgb2gray
from skimage.morphology import label
from scipy import ndimage as ndi
import zipfile

from keras.models import Model, load_model
from keras.layers import Input, Dropout, SeparableConv2D, LeakyReLU, BatchNormalization, Add, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Activation, ZeroPadding2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K

import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
K.set_session(session)

# Set some parameters
BS = 32
EPOCHS_1 = 50
EPOCHS_2 = 50
ORI_D = 101
TRAIN_ZIP = '../input/train.zip'
TEST_ZIP = '../input/test.zip'
TRAIN_PATH = '../input/train/'
TEST_PATH = '../input/test/'
TRAIN_CSV = '../input/train.csv'
DEPTH_CSV = '../input/depths.csv'

if not os.path.exists(TRAIN_PATH):
    zip_ref = zipfile.ZipFile(TRAIN_ZIP, 'r')
    zip_ref.extractall(TRAIN_PATH)
    zip_ref.close()
if not os.path.exists(TEST_PATH):
    zip_ref = zipfile.ZipFile(TEST_ZIP, 'r')
    zip_ref.extractall(TEST_PATH)
    zip_ref.close()
if not os.path.exists('./models'):
    os.makedirs('./models')
print(os.listdir(TRAIN_PATH))
# Out:
# Using TensorFlow backend.
# ['masks', 'images']

# %%
def rle_encoding(x, order='F', to_str=True):
    dots = np.where(x.flatten(order=order) == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    if to_str:
        return ' '.join(str(y) for y in run_lengths)
    return run_lengths

# %%
train_csv = pd.read_csv(TRAIN_CSV)
depth_csv = pd.read_csv(DEPTH_CSV)
test_csv = depth_csv[~depth_csv.index.isin(train_csv.index)]
del depth_csv
gc.collect()
# Out:
# 7

# %%
X_train = []
Y_train = [] 

print('Getting train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_csv.id), total=len(train_csv.id)):
    path = TRAIN_PATH
    img = imread(path + 'images/' + id_ + '.png')[...,0].astype(np.uint8)
    assert img.ndim==2
    assert img.shape[0]==ORI_D and img.shape[1]==ORI_D
    X_train.append(img)
    mask = np.squeeze(imread(path + 'masks/' + id_ + '.png')>0).astype(np.uint8)
    assert mask.ndim==2
    Y_train.append(mask)
del img, mask
gc.collect()
# Out:
# Getting train images and masks ...
# 100%|██████████| 4000/4000 [00:01<00:00, 2020.75it/s]
# 0

# %%
# Check if training data looks all right
ix = np.random.randint(0, len(train_csv.id))
plt.imshow(X_train[ix], cmap='gray')
plt.show()
plt.imshow(Y_train[ix], cmap='gray')
plt.show()

# %%
def custom_loss(y_true, y_pred_):
    
    y_pred = K.sigmoid(y_pred_)
    
    def dice_coef(y_true, y_pred): 
        return (2.* K.sum(y_true*y_pred) + 1) / (K.sum(y_true) + K.sum(y_pred) + 1) # scaler
    
    s_dice_coef = dice_coef(y_true, y_pred) # scaler
    s_bce = K.mean(K.binary_crossentropy(y_true, y_pred)) # scaler
    loss = 0.5*s_bce - s_dice_coef + 1. # scaler [0, inf)
    
    return loss # scaler [0, inf)

# %%
# Define IoU metric
def score_numpy(Ys, Ps):
    th = 0
    iou_ths = np.arange(0.0, 1.0, 0.05)
    Ps = Ps.reshape(Ps.shape[0], -1).copy()
    Ys = Ys.reshape(Ys.shape[0], -1).copy()
    for n, P in enumerate(Ps):
        Ps[n] = P>th
    Ps = Ps.astype(np.bool)
    Ys = Ys.astype(np.bool)
    TPs = np.zeros_like(iou_ths, dtype=np.float32)
    FPs = np.zeros_like(iou_ths, dtype=np.float32)
    FNs = np.zeros_like(iou_ths, dtype=np.float32)
    for Y, P in zip(Ys, Ps):
        iou = (Y&P).sum() / ((Y|P).sum()+1e-9)
        Y_sum = Y.sum()
        P_sum = P.sum()
        for n, iou_th in enumerate(iou_ths):
            if iou>=iou_th: # TP
                TPs[n]+=1
            elif Y_sum<=0 and P_sum>0: # FP
                FPs[n]+=1
            elif Y_sum>0 and P_sum<=0: # FN
                FNs[n]+=1
    return np.mean(TPs / (TPs+FPs+FNs))

def score(label, pred):
    metric_value = tf.py_func(score_numpy, [label, pred], tf.float32)
    return metric_value

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard


# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss


def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %%
def build_model():
    def conv(f, k=3, act=None):
        return Conv2D(f, (k, k), activation=act, kernel_initializer='he_normal', padding='same', use_bias=False)
    def sep_conv(f, k=3, act=None):
        return SeparableConv2D(f, (k, k), activation=act, kernel_initializer='he_normal', padding='same', use_bias=False)
    def _res_conv(inputs, f): # very simple residual module
        channels = int(inputs.shape[-1])
        
        cs = inputs
        
        cs = BatchNormalization() (cs)
        cs = Activation('elu') (cs)
        cs = sep_conv(f, 3, act=None) (cs)
        
        cs = BatchNormalization() (cs)
        cs = Activation('elu') (cs)
        cs = sep_conv(f, 3, act=None) (cs)
        
        if f!=channels:
            t1 = conv(f, 1, None) (inputs) # identity mapping
        else:
            t1 = inputs
        
        out = Add()([t1, cs]) # t1 + c2
        return out
    def pool():
        return MaxPooling2D((2, 2))
    def up(inputs, pad='same', output_shape=None):
        # upsampled = Conv2DTranspose(int(inputs.shape[-1]), (3, 3), strides=(2, 2), kernel_initializer='he_normal', padding=pad) (inputs)
        # upsampled = Lambda(lambda x: tf.image.resize_bilinear(x, output_shape, align_corners=True)) (inputs)
        upsampled = Lambda(lambda x: tf.image.resize_images(x, output_shape, method=tf.image.ResizeMethod.BICUBIC, align_corners=True)) (inputs)
        return upsampled
    
    inputs = Input(shape=(ORI_D, ORI_D, 1))
    preprocess1 = Lambda(lambda x: x/255.0) (inputs)
    
    r = 20
    rep = 4
    mid_rep = 3
    x = preprocess1
    
    skip_connections = []
    pad_mode = ['same', 'valid', 'same', 'valid']
    
    for t in range(rep):
        x = sep_conv(r*int(2**t), 3, None) (x)
        x = _res_conv(x, r*int(2**t))
        x = _res_conv(x, r*int(2**t))
        x = BatchNormalization() (x)
        x = Activation('elu') (x)
        skip_connections.append(x)
        x = pool() (x)
    
    x = sep_conv(r*int(2**rep), 3, None) (x)
    for t in range(mid_rep):
        x = _res_conv(x, r*int(2**rep))
    
    for t, s, p in zip(reversed(range(rep)), reversed(skip_connections), pad_mode):
        x = BatchNormalization() (x)
        x = Activation('elu') (x)
        x = up(x, p, K.int_shape(s)[1:3])
        x = concatenate([s, x])
        x = sep_conv(r*int(2**t), 3, None) (x)
        x = _res_conv(x, r*int(2**t))
        x = _res_conv(x, r*int(2**t))
    x = BatchNormalization() (x)
    x = Activation('elu') (x)
    outputs = Conv2D(1, (1, 1), activation=None, kernel_initializer='he_normal', padding='valid', use_bias=True) (x)
    return Model([inputs], [outputs])

# %%
model = build_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 101, 101, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 101, 101, 20) 29          lambda_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 101, 101, 20) 80          separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 101, 101, 20) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 101, 101, 20) 580         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 101, 101, 20) 80          separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 101, 101, 20) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 101, 101, 20) 580         activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 101, 101, 20) 0           separable_conv2d_1[0][0]
#                                                                  separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 101, 101, 20) 80          add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 101, 101, 20) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 101, 101, 20) 580         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 101, 101, 20) 80          separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 101, 101, 20) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 101, 101, 20) 580         activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 101, 101, 20) 0           add_1[0][0]
#                                                                  separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 101, 101, 20) 80          add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 101, 101, 20) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 20)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 50, 50, 40)   980         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 50, 40)   160         separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50, 50, 40)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 50, 50, 40)   1960        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 50, 40)   160         separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 50, 50, 40)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 50, 50, 40)   1960        activation_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 50, 50, 40)   0           separable_conv2d_6[0][0]
#                                                                  separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 50, 50, 40)   160         add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50, 50, 40)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 50, 50, 40)   1960        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 50, 40)   160         separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 50, 50, 40)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_10 (SeparableC (None, 50, 50, 40)   1960        activation_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 50, 40)   0           add_3[0][0]
#                                                                  separable_conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 50, 50, 40)   160         add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50, 50, 40)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 40)   0           activation_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_11 (SeparableC (None, 25, 25, 80)   3560        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 80)   320         separable_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 80)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_12 (SeparableC (None, 25, 25, 80)   7120        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 80)   320         separable_conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 80)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_13 (SeparableC (None, 25, 25, 80)   7120        activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 25, 25, 80)   0           separable_conv2d_11[0][0]
#                                                                  separable_conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 80)   320         add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 80)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_14 (SeparableC (None, 25, 25, 80)   7120        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 80)   320         separable_conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 80)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_15 (SeparableC (None, 25, 25, 80)   7120        activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 25, 25, 80)   0           add_5[0][0]
#                                                                  separable_conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 80)   320         add_6[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 80)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 80)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_16 (SeparableC (None, 12, 12, 160)  13520       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 12, 12, 160)  640         separable_conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 12, 12, 160)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_17 (SeparableC (None, 12, 12, 160)  27040       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 12, 12, 160)  640         separable_conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 12, 12, 160)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_18 (SeparableC (None, 12, 12, 160)  27040       activation_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 12, 12, 160)  0           separable_conv2d_16[0][0]
#                                                                  separable_conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 12, 12, 160)  640         add_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 12, 12, 160)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_19 (SeparableC (None, 12, 12, 160)  27040       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 12, 12, 160)  640         separable_conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 12, 12, 160)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_20 (SeparableC (None, 12, 12, 160)  27040       activation_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 12, 12, 160)  0           add_7[0][0]
#                                                                  separable_conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 12, 12, 160)  640         add_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 12, 12, 160)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 160)    0           activation_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_21 (SeparableC (None, 6, 6, 320)    52640       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 6, 6, 320)    1280        separable_conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 320)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_22 (SeparableC (None, 6, 6, 320)    105280      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 6, 6, 320)    1280        separable_conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 6, 6, 320)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_23 (SeparableC (None, 6, 6, 320)    105280      activation_22[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 6, 6, 320)    0           separable_conv2d_21[0][0]
#                                                                  separable_conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 6, 6, 320)    1280        add_9[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 6, 6, 320)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_24 (SeparableC (None, 6, 6, 320)    105280      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 6, 6, 320)    1280        separable_conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 6, 6, 320)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_25 (SeparableC (None, 6, 6, 320)    105280      activation_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 6, 6, 320)    0           add_9[0][0]
#                                                                  separable_conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 6, 6, 320)    1280        add_10[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 6, 6, 320)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_26 (SeparableC (None, 6, 6, 320)    105280      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 6, 6, 320)    1280        separable_conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 6, 6, 320)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_27 (SeparableC (None, 6, 6, 320)    105280      activation_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 6, 6, 320)    0           add_10[0][0]
#                                                                  separable_conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 6, 6, 320)    1280        add_11[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 6, 6, 320)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 12, 12, 320)  0           activation_27[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 480)  0           activation_20[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_28 (SeparableC (None, 12, 12, 160)  81120       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 12, 12, 160)  640         separable_conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 12, 12, 160)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_29 (SeparableC (None, 12, 12, 160)  27040       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 12, 12, 160)  640         separable_conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 160)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_30 (SeparableC (None, 12, 12, 160)  27040       activation_29[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 12, 12, 160)  0           separable_conv2d_28[0][0]
#                                                                  separable_conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 160)  640         add_12[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 160)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_31 (SeparableC (None, 12, 12, 160)  27040       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 12, 12, 160)  640         separable_conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 160)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_32 (SeparableC (None, 12, 12, 160)  27040       activation_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 12, 12, 160)  0           add_12[0][0]
#                                                                  separable_conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 12, 12, 160)  640         add_13[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 160)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 25, 25, 160)  0           activation_32[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 25, 25, 240)  0           activation_15[0][0]
#                                                                  lambda_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_33 (SeparableC (None, 25, 25, 80)   21360       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 25, 25, 80)   320         separable_conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 25, 25, 80)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_34 (SeparableC (None, 25, 25, 80)   7120        activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 25, 25, 80)   320         separable_conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 25, 25, 80)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_35 (SeparableC (None, 25, 25, 80)   7120        activation_34[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 25, 25, 80)   0           separable_conv2d_33[0][0]
#                                                                  separable_conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 25, 25, 80)   320         add_14[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 25, 25, 80)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_36 (SeparableC (None, 25, 25, 80)   7120        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 25, 25, 80)   320         separable_conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 25, 25, 80)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_37 (SeparableC (None, 25, 25, 80)   7120        activation_36[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 25, 25, 80)   0           add_14[0][0]
#                                                                  separable_conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 25, 25, 80)   320         add_15[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 25, 25, 80)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 50, 50, 80)   0           activation_37[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 50, 50, 120)  0           activation_10[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_38 (SeparableC (None, 50, 50, 40)   5880        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 50, 50, 40)   160         separable_conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 50, 50, 40)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_39 (SeparableC (None, 50, 50, 40)   1960        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 50, 50, 40)   160         separable_conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 50, 50, 40)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_40 (SeparableC (None, 50, 50, 40)   1960        activation_39[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 50, 50, 40)   0           separable_conv2d_38[0][0]
#                                                                  separable_conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 50, 50, 40)   160         add_16[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 50, 50, 40)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_41 (SeparableC (None, 50, 50, 40)   1960        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 50, 50, 40)   160         separable_conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 50, 50, 40)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_42 (SeparableC (None, 50, 50, 40)   1960        activation_41[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 50, 50, 40)   0           add_16[0][0]
#                                                                  separable_conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 50, 50, 40)   160         add_17[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 50, 50, 40)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 101, 101, 40) 0           activation_42[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 101, 101, 60) 0           activation_5[0][0]
#                                                                  lambda_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_43 (SeparableC (None, 101, 101, 20) 1740        concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 101, 101, 20) 80          separable_conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 101, 101, 20) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_44 (SeparableC (None, 101, 101, 20) 580         activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 101, 101, 20) 80          separable_conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 101, 101, 20) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_45 (SeparableC (None, 101, 101, 20) 580         activation_44[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 101, 101, 20) 0           separable_conv2d_43[0][0]
#                                                                  separable_conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 101, 101, 20) 80          add_18[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 101, 101, 20) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_46 (SeparableC (None, 101, 101, 20) 580         activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 101, 101, 20) 80          separable_conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 101, 101, 20) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_47 (SeparableC (None, 101, 101, 20) 580         activation_46[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 101, 101, 20) 0           add_18[0][0]
#                                                                  separable_conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 101, 101, 20) 80          add_19[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 101, 101, 20) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 101, 101, 1)  21          activation_47[0][0]
# ==================================================================================================
# Total params: 1,127,090
# Trainable params: 1,116,610
# Non-trainable params: 10,480
# __________________________________________________________________________________________________

# %%
from keras.utils import Sequence
import cv2
from sklearn.utils import shuffle
from skimage.transform import AffineTransform, warp
import copy
import imgaug as ia
from imgaug import augmenters as iaa

class data_generator(Sequence):
    def __init__(self, data, label, batch_size=4, training=True):
        self.data = data
        self.label= label
        self.batch_size = batch_size
        self.training = training
        self.seq_color = iaa.Sequential(
            [
                iaa.SomeOf((0, 2),
                    [
                        iaa.Dropout((0.01, 0.05)),
                        iaa.ContrastNormalization((0.975, 1.025)),
                        
                    ], random_order=True
                )
            ], random_order=True
        )
    def __len__(self):
        return int(np.ceil(float(len(self.data))/self.batch_size))
    def on_epoch_end(self):
        if self.training: self.data, self.label = shuffle(self.data, self.label)
    def __getitem__(self, i):
        l_bound =  i    * self.batch_size
        r_bound = (i+1) * self.batch_size
        if r_bound>len(self.data): # ensure every iteration has the same batch size
            r_bound = len(self.data)
            l_bound = r_bound - self.batch_size
        dat_que = np.empty((self.batch_size, ORI_D, ORI_D, 1), dtype=np.uint8)
        lab_que = np.empty((self.batch_size, ORI_D, ORI_D, 1), dtype=np.uint8)
        for n, index in enumerate(range(l_bound, r_bound)):
            img = copy.deepcopy(self.data[index]).astype(np.float32) / 255.
            lab = copy.deepcopy(self.label[index]).astype(np.float32)
            if self.training:
                if np.random.rand() < .5: # flip horizontal
                    img = np.flip(img, 1)
                    lab = np.flip(lab, 1)

                if np.random.rand()<0.1:
                    a = .02 # amptitude
                    t  = np.random.uniform(1-a,1+a)
                    img = np.clip(img * t, 0, 1) # channel wise amplify
                
                if np.random.rand()<0.1:
                    up = np.random.uniform(0.975, 1.025) # change gamma
                    img = np.clip(img**up, 0, 1) # apply gamma and convert back to range [0,255]
                
                if np.random.rand()<0.1:
                    sigma = np.random.rand()*0.02
                    img = np.clip(img + np.random.randn(*img.shape)*sigma, 0, 1)
                
                if np.random.rand() < 0.3:
                    crop_ratio = np.random.uniform(0.01, 0.1, size=4)
                    u, r, d, l = np.round(crop_ratio * np.array([img.shape[0], img.shape[1]]*2)).astype(np.uint8)
                    img = img[u:-d,l:-r] # crop image
                    lab = lab[u:-d,l:-r] # crop image
                
                if np.random.rand() < 0.2:
                    img = np.clip(self.seq_color.augment_image(img), 0, 1)
            ### end of data augmentation ###

            img = np.clip(img.astype(np.float32)*255,0, 255).astype(np.uint8)
            lab = np.round(np.clip(lab.astype(np.float32),0, 1)).astype(np.uint8)
            
            if img.shape[0]!=ORI_D or img.shape[1]!=ORI_D:
                diffr = ORI_D-img.shape[0] # must >= 0
                diffc = ORI_D-img.shape[1] # must >= 0
                padr1 = np.random.randint(diffr+1)
                padr2 = diffr-padr1
                padc1 = np.random.randint(diffc+1)
                padc2 = diffc-padc1
                img = np.pad(img, ((padr1,padr2),(padc1,padc2)), 'wrap')
                lab = np.pad(lab, ((padr1,padr2),(padc1,padc2)), 'wrap')

            dat_que[n,...,0] = img
            lab_que[n,...,0] = lab
        return dat_que, lab_que

# %%
coverage = np.asarray([ x.sum() / (ORI_D**2) for x in Y_train ])
coverage_lev = np.linspace(0, 1, 20)
import bisect
coverage_stratify = []
for cov in coverage:
    coverage_stratify.append(bisect.bisect_left(coverage_lev, cov))

# %%
# https://www.surveysystem.com/sscalc.htm
from sklearn.model_selection import train_test_split
X_train, X_val1, Y_train, Y_val1, coverage_stratify, _ = train_test_split(X_train, Y_train, coverage_stratify, test_size=380, shuffle=True, stratify = coverage_stratify)
X_train, X_val2, Y_train, Y_val2, coverage_stratify, _ = train_test_split(X_train, Y_train, coverage_stratify, test_size=500, shuffle=True, stratify = coverage_stratify)

del coverage, coverage_lev, coverage_stratify

# %%
train_generator = data_generator(X_train, Y_train, batch_size=BS, training=True)

# %%
import multiprocessing
from keras.optimizers import Adam
checkpointer_best = ModelCheckpoint('./models/best.h5', monitor='val_score', mode='max', verbose=1, save_best_only=True)

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8,
                              patience=2, min_lr=0.00001, mode='min')
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=10)
model.compile(loss=custom_loss, optimizer=Adam(lr=0.001), metrics=[score])
history = model.fit_generator(train_generator,
                              steps_per_epoch= len(train_generator), 
                              epochs=EPOCHS_1, 
                              validation_data=(np.asarray(X_val1)[...,np.newaxis], np.asarray(Y_val1)[...,np.newaxis]), 
                              callbacks=[checkpointer_best, reduce_lr, early_stop],
                              workers= max(1, multiprocessing.cpu_count()-3),
                              use_multiprocessing= True,
                              shuffle = True
                              )
# Out:
# Epoch 1/50
# 89/98 [==========================>...] - ETA: 6s - loss: 0.7439 - score: 0.4071

# %%
plt.plot(history.history['score'])
plt.plot(history.history['val_score'])
plt.title('LB')
plt.ylabel('LB @threshold=0.0')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper right')
plt.show()

# %%
X_train += X_val1
Y_train += Y_val1
del X_val1, Y_val1
gc.collect()
train_generator = data_generator(X_train, Y_train, batch_size=BS, training=True)

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8,
                              patience=2, min_lr=0.00001, mode='min')
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=25)
model.load_weights('./models/best.h5')
model.compile(loss=lovasz_loss, optimizer=Adam(lr=0.001), metrics=[score])
history = model.fit_generator(train_generator,
                              steps_per_epoch= len(train_generator), 
                              epochs=EPOCHS_2, 
                              validation_data=(np.asarray(X_val2)[...,np.newaxis], np.asarray(Y_val2)[...,np.newaxis]), 
                              callbacks=[checkpointer_best, reduce_lr, early_stop],
                              workers= max(1, multiprocessing.cpu_count()-3),
                              use_multiprocessing= True,
                              shuffle = True
                              )
del train_generator
gc.collect()

# %%
plt.plot(history.history['score'])
plt.plot(history.history['val_score'])
plt.title('LB')
plt.ylabel('LB @threshold=0.0')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper right')
plt.show()

# %%
model.load_weights('./models/best.h5')
preds_val = model.predict(np.asarray(X_val2)[...,np.newaxis], batch_size=BS, verbose=1)

# %%
# Perform a sanity check on some random training samples
ix = np.random.randint(0, len(preds_val))
print(ix)
shape = Y_val2[ix].shape[:2]
plt.imshow(X_val2[ix])
plt.show()
plt.imshow(Y_val2[ix])
plt.show()
preds = np.squeeze(preds_val[ix])
preds = preds>0
plt.imshow(preds)
plt.show()

# %%
del X_train, Y_train, X_val2, Y_val2
gc.collect()

# %%
sub_rles = []
x_test = []
print('Reading testing data...')
for n, id_ in tqdm(enumerate(test_csv.id), total=len(test_csv.id)):
    path = TEST_PATH
    img = imread(path + 'images/' + id_ + '.png')[...,0].astype(np.uint8)[...,np.newaxis]
    x_test.append(img)

print('Predicting...')
preds = model.predict(np.asarray(x_test), batch_size=BS, verbose=1)[...,0]
print('Convert to RLE...')
for pred in tqdm(preds, total=len(preds)):
    pred_thresholded = (pred>0).astype(np.bool)
    rle = rle_encoding(pred_thresholded)
    sub_rles.append(rle)
sub = pd.DataFrame()
sub['id'] = test_csv.id
sub['rle_mask'] = sub_rles
sub.to_csv('salty.csv', index=False)
print('Done!')
